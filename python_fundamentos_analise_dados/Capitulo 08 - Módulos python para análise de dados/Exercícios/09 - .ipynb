# %%
import pandas as pd
import requests
import json

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
json_resp = json.loads(resp.content.decode('utf-8'))
df = pd.DataFrame(json_resp)
df
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url         id  \
# 0     https://github.com/pandas-dev/pandas/pull/30619  544627499
# 1   https://github.com/pandas-dev/pandas/issues/30618  544617303
# 2   https://github.com/pandas-dev/pandas/issues/30616  544450780
# 3     https://github.com/pandas-dev/pandas/pull/30615  544442599
# 4   https://github.com/pandas-dev/pandas/issues/30614  544438638
# 5     https://github.com/pandas-dev/pandas/pull/30613  544432101
# 6     https://github.com/pandas-dev/pandas/pull/30612  544423802
# 7   https://github.com/pandas-dev/pandas/issues/30609  544414486
# 8     https://github.com/pandas-dev/pandas/pull/30603  544390619
# 9   https://github.com/pandas-dev/pandas/issues/30593  544299776
# 10  https://github.com/pandas-dev/pandas/issues/30590  544283036
# 11  https://github.com/pandas-dev/pandas/issues/30589  544268553
# 12    https://github.com/pandas-dev/pandas/pull/30588  544265607
# 13    https://github.com/pandas-dev/pandas/pull/30584  544220829
# 14    https://github.com/pandas-dev/pandas/pull/30583  544206632
# 15    https://github.com/pandas-dev/pandas/pull/30582  544190287
# 16    https://github.com/pandas-dev/pandas/pull/30578  544157086
# 17  https://github.com/pandas-dev/pandas/issues/30576  544084978
# 18    https://github.com/pandas-dev/pandas/pull/30574  544034858
# 19    https://github.com/pandas-dev/pandas/pull/30570  544016899
# 20    https://github.com/pandas-dev/pandas/pull/30562  543984943
# 21  https://github.com/pandas-dev/pandas/issues/30559  543905874
# 22  https://github.com/pandas-dev/pandas/issues/30555  543791405
# 23    https://github.com/pandas-dev/pandas/pull/30553  543705194
# 24  https://github.com/pandas-dev/pandas/issues/30552  543610762
# 25    https://github.com/pandas-dev/pandas/pull/30546  543549207
# 26  https://github.com/pandas-dev/pandas/issues/30543  543517753
# 27  https://github.com/pandas-dev/pandas/issues/30539  543435852
# 28  https://github.com/pandas-dev/pandas/issues/30537  543418429
# 29  https://github.com/pandas-dev/pandas/issues/30533  543330427
#
#                              node_id  number  \
# 0   MDExOlB1bGxSZXF1ZXN0MzU4Njk4Njcy   30619
# 1           MDU6SXNzdWU1NDQ2MTczMDM=   30618
# 2           MDU6SXNzdWU1NDQ0NTA3ODA=   30616
# 3   MDExOlB1bGxSZXF1ZXN0MzU4NTQ5OTgz   30615
# 4           MDU6SXNzdWU1NDQ0Mzg2Mzg=   30614
# 5   MDExOlB1bGxSZXF1ZXN0MzU4NTQxNzE1   30613
# 6   MDExOlB1bGxSZXF1ZXN0MzU4NTM1NTIw   30612
# 7           MDU6SXNzdWU1NDQ0MTQ0ODY=   30609
# 8   MDExOlB1bGxSZXF1ZXN0MzU4NTExOTI3   30603
# 9           MDU6SXNzdWU1NDQyOTk3NzY=   30593
# 10          MDU6SXNzdWU1NDQyODMwMzY=   30590
# 11          MDU6SXNzdWU1NDQyNjg1NTM=   30589
# 12  MDExOlB1bGxSZXF1ZXN0MzU4NDE3ODQx   30588
# 13  MDExOlB1bGxSZXF1ZXN0MzU4MzgzMjUy   30584
# 14  MDExOlB1bGxSZXF1ZXN0MzU4MzcxODMw   30583
# 15  MDExOlB1bGxSZXF1ZXN0MzU4MzU4NTc1   30582
# 16  MDExOlB1bGxSZXF1ZXN0MzU4MzMxMzg5   30578
# 17          MDU6SXNzdWU1NDQwODQ5Nzg=   30576
# 18  MDExOlB1bGxSZXF1ZXN0MzU4MjM1MzE3   30574
# 19  MDExOlB1bGxSZXF1ZXN0MzU4MjIwNzUy   30570
# 20  MDExOlB1bGxSZXF1ZXN0MzU4MTk0ODk2   30562
# 21          MDU6SXNzdWU1NDM5MDU4NzQ=   30559
# 22          MDU6SXNzdWU1NDM3OTE0MDU=   30555
# 23  MDExOlB1bGxSZXF1ZXN0MzU3OTYyNzAx   30553
# 24          MDU6SXNzdWU1NDM2MTA3NjI=   30552
# 25  MDExOlB1bGxSZXF1ZXN0MzU3ODE4MTE1   30546
# 26          MDU6SXNzdWU1NDM1MTc3NTM=   30543
# 27          MDU6SXNzdWU1NDM0MzU4NTI=   30539
# 28          MDU6SXNzdWU1NDM0MTg0Mjk=   30537
# 29          MDU6SXNzdWU1NDMzMzA0Mjc=   30533
#
#                                                 title  ... assignee assignees  \
# 0   TYP: enable strict_equality to prohibit compar...  ...     None        []
# 1   'Categorical' from output of 'factorize' has d...  ...     None        []
# 2                                              encode  ...     None        []
# 3                           DEPR: is_copy arg of take  ...     None        []
# 4   ENH: Create a devcontainer.json env to work wi...  ...     None        []
# 5                        TYP: Add TypeVars to NDFrame  ...     None        []
# 6   CLN: replacing str.format with f-strings in se...  ...     None        []
# 7                 Error on Warnings From C Extensions  ...     None        []
# 8   Added 'pearson' to methods list in pandas/core...  ...     None        []
# 9   Pandas date_range does not work when using per...  ...     None        []
# 10                     DOC: Add info on dtype strings  ...     None        []
# 11  How can I force Pandas `read_html` function to...  ...     None        []
# 12                     BUG: validate Index data is 1D  ...     None        []
# 13    ENH: Add dropna in groupby to allow NaN in keys  ...     None        []
# 14       WIP: Restructuring all builds (NOT TO MERGE)  ...     None        []
# 15          TYP: Add types to top-level funcs, step 2  ...     None        []
# 16                ENH: Add ignore_index to sort_index  ...     None        []
# 17                      ADMIN: display issue metrics   ...     None        []
# 18             API: Raise when setting name via level  ...     None        []
# 19         CLN: refactor tests in test_moments_ewm.py  ...     None        []
# 20  ENH: Allow absolute precision in assert_almost...  ...     None        []
# 21  BUG: Rolling aggregations on grouped data igno...  ...     None        []
# 22  read_csv s3 file parameter memory_map default ...  ...     None        []
# 23  TST/BUG: fix incorrectly-passing Exception in ...  ...     None        []
# 24  PERF: groupby with many empty groups memory bl...  ...     None        []
# 25  DEPR: DataFrame GroupBy indexing with single i...  ...     None        []
# 26  PERF: Timestamp/Timedelta constructors when pa...  ...     None        []
# 27  DISC: enable disallow_any_generics for mypy in...  ...     None        []
# 28  Unpin ipython 7.10.1 once ipython 7.11.1 released  ...     None        []
# 29     Inconsistent index in result of groupby apply   ...     None        []
#
#                                             milestone  comments  \
# 0                                                None         0
# 1                                                None         2
# 2                                                None         1
# 3                                                None         1
# 4                                                None         1
# 5                                                None         0
# 6   {'url': 'https://api.github.com/repos/pandas-d...         0
# 7                                                None         3
# 8                                                None         0
# 9                                                None         1
# 10                                               None         9
# 11                                               None         0
# 12                                               None         3
# 13                                               None         0
# 14                                               None         0
# 15  {'url': 'https://api.github.com/repos/pandas-d...        12
# 16                                               None         0
# 17                                               None         0
# 18  {'url': 'https://api.github.com/repos/pandas-d...        11
# 19                                               None         0
# 20                                               None        12
# 21                                               None         0
# 22                                               None         2
# 23                                               None         0
# 24                                               None         1
# 25                                               None         2
# 26  {'url': 'https://api.github.com/repos/pandas-d...         0
# 27                                               None         1
# 28                                               None         1
# 29                                               None         0
#
#               created_at            updated_at closed_at  author_association  \
# 0   2020-01-02T15:36:41Z  2020-01-02T16:56:52Z      None              MEMBER
# 1   2020-01-02T15:10:35Z  2020-01-02T16:46:51Z      None                NONE
# 2   2020-01-02T05:26:21Z  2020-01-02T07:43:56Z      None                NONE
# 3   2020-01-02T04:28:17Z  2020-01-02T07:37:52Z      None         CONTRIBUTOR
# 4   2020-01-02T03:56:56Z  2020-01-02T05:03:21Z      None                NONE
# 5   2020-01-02T03:08:10Z  2020-01-02T16:57:22Z      None         CONTRIBUTOR
# 6   2020-01-02T02:00:41Z  2020-01-02T09:59:30Z      None         CONTRIBUTOR
# 7   2020-01-02T00:16:52Z  2020-01-02T02:47:50Z      None              MEMBER
# 8   2020-01-01T19:32:52Z  2020-01-02T02:43:39Z      None         CONTRIBUTOR
# 9   2020-01-01T02:01:00Z  2020-01-01T18:47:34Z      None                NONE
# 10  2019-12-31T22:44:06Z  2020-01-02T16:52:11Z      None         CONTRIBUTOR
# 11  2019-12-31T20:49:23Z  2019-12-31T20:49:23Z      None                NONE
# 12  2019-12-31T20:31:38Z  2020-01-02T16:38:12Z      None              MEMBER
# 13  2019-12-31T16:07:32Z  2020-01-02T14:06:34Z      None         CONTRIBUTOR
# 14  2019-12-31T14:55:24Z  2019-12-31T15:51:47Z      None              MEMBER
# 15  2019-12-31T13:32:48Z  2020-01-02T16:51:50Z      None         CONTRIBUTOR
# 16  2019-12-31T10:46:18Z  2020-01-01T21:35:09Z      None         CONTRIBUTOR
# 17  2019-12-31T04:30:05Z  2019-12-31T04:30:45Z      None         CONTRIBUTOR
# 18  2019-12-30T22:52:50Z  2020-01-02T15:13:33Z      None         CONTRIBUTOR
# 19  2019-12-30T21:28:36Z  2020-01-01T02:30:09Z      None         CONTRIBUTOR
# 20  2019-12-30T19:23:21Z  2020-01-02T16:16:24Z      None                NONE
# 21  2019-12-30T14:53:57Z  2019-12-30T14:53:57Z      None                NONE
# 22  2019-12-30T08:18:05Z  2019-12-31T02:42:14Z      None                NONE
# 23  2019-12-30T03:23:00Z  2019-12-30T16:41:42Z      None              MEMBER
# 24  2019-12-29T22:59:51Z  2019-12-30T09:39:13Z      None              MEMBER
# 25  2019-12-29T20:11:10Z  2020-01-02T04:05:51Z      None                NONE
# 26  2019-12-29T18:45:17Z  2019-12-30T07:33:20Z      None              MEMBER
# 27  2019-12-29T15:08:25Z  2019-12-30T09:40:50Z      None              MEMBER
# 28  2019-12-29T14:22:59Z  2020-01-01T17:53:03Z      None              MEMBER
# 29  2019-12-29T07:15:53Z  2019-12-29T07:15:53Z      None         CONTRIBUTOR
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                                  body
# 0   …g types\r\n\r\nBy default, mypy allows always...
# 1   If I call `pd.Categorical` using the results o...
# 2   #### Code Sample, a copy-pastable example if p...
# 3   - [x] closes #27357\r\n- [x] tests added / pas...
# 4   VS Code has a great feature where you can work...
# 5   Adding TypeVars to NDFrame methods that don't ...
# 6   - [ ] xref #29547 \r\n- [ ] tests added / pass...
# 7   May differ on other platforms, but currently I...
# 8   - [x] ref https://github.com/pandas-dev/pandas...
# 9   This code works fine\r\n\r\n````\r\npd.date_ra...
# 10  #### Problem description\r\n\r\nI've been stud...
# 11  Is there a possible way to convert the field f...
# 12  - [x] closes #13601\r\n- [x] closes #27125\r\n...
# 13  - [x] closes #3729 \r\n- [x] tests added / pas...
# 14  - [X] closes #29685\r\n\r\nSo far just testing...
# 15  Next step to #30565.\r\n\r\nNext up will be th...
# 16  - [x] closes #30114\r\n- [x] tests added / pas...
# 17  came across this blog / repo which shows nice ...
# 18  Closes https://github.com/pandas-dev/pandas/is...
# 19  - [ ] xref: #30486 #30542 \r\n- [ ] tests adde...
# 20  Greetings! This is my first pull-request on an...
# 21  It appears that rolling aggregations on groupb...
# 22  #### Code Sample\r\n\r\n```python\r\n# code 1\...
# 23  A `raise` is indented one indent further than ...
# 24  Suppose we have a Categorical with many unused...
# 25  \r\n\r\n- [x] closes #23566\r\n- [x] tests add...
# 26  The `Timestamp` constructor's performance coul...
# 27  This flag disallows usage of generic types tha...
# 28  xref https://github.com/cython/cython/pull/329...
# 29  ### I'm not really sure if this is an "issue" ...
#
# [30 rows x 24 columns]
