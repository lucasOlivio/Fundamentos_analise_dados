# %%
import pandas as pd
import requests
import json

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'JSON Date Handling 1.0 Regressions'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    30977                 JSON Date Handling 1.0 Regressions
# 1    30976      BUG: ensure_datetime64ns with bigendian array
# 2    30975  AssertionError from Series.append(DataFrame) w...
# 3    30974                        DOC: Fix isort output in CI
# 4    30973                     Compat for util.testing import
# 5    30972                                   whatsnew for 1.1
# 6    30971  BUG: reductions for IntegerArray should return...
# 7    30969  str.extract(expand=False) on a string typed se...
# 8    30967        DataFrame.diff fails with nullable integers
# 9    30966  str accessor functions returns float(NaN) inst...
# 10   30965  DataFrame.set_index when setting a duplicate n...
# 11   30964  DOC: Remove tips and tricks section page from ...
# 12   30962  AttributeError: 'FrameFixed' object has no att...
# 13   30960    [BUG] -1 to the power of pd.NA was returning -1
# 14   30959                          ENH: Add Stata 119 writer
# 15   30958   pd.Series.sum() returns nan for Int64 with pd.NA
# 16   30956    BUG: rpow with -1 and pd.NA should return pd.NA
# 17   30954  REF: remove method and tolerance keywords from...
# 18   30953                  Persistent groupby future warning
# 19   30950  REF: handle searchsorted casting within Dateti...
# 20   30949  DOC: Clarified documentation for convert_dates...
# 21   30948  REF: do all casting _before_ call to DatetimeE...
# 22   30947                              TYP: NDFrame.resample
# 23   30945  BUG: Use self._constructor_sliced in df._reduc...
# 24   30944     BUG: pd.NA is not compatible with searchsorted
# 25   30943  BUG: Fix MutliIndexed unstack failures at tupl...
# 26   30937  ENH: Add engine keyword to expanding.apply to ...
# 27   30936  ENH: Add engine keyword argument to expanding....
# 28   30935                 CLN: remove unused NDFrame methods
# 29   30933  DOC: Replace old string formatting syntax in c...
#
#                                                labels state
# 0   [{'id': 49379259, 'node_id': 'MDU6TGFiZWw0OTM3...  open
# 1   [{'id': 211840, 'node_id': 'MDU6TGFiZWwyMTE4ND...  open
# 2   [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 3   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 4                                                  []  open
# 5   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7                                                  []  open
# 8                                                  []  open
# 9   [{'id': 849023693, 'node_id': 'MDU6TGFiZWw4NDk...  open
# 10  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 11  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 12  [{'id': 47229190, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 17                                                 []  open
# 18  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 19  [{'id': 1218227310, 'node_id': 'MDU6TGFiZWwxMj...  open
# 20  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 21                                                 []  open
# 22  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 23  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 24  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 27  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 28  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 29  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
